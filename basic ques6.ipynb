# %%
import pandas as pd

df = pd.DataFrame({
    'Student': ['Emma', 'Liam', 'Olivia'],
    'Grade': ['A', 'B', 'C']
})

grade_map = {'A': 4, 'B': 3}

# %%
df['Points'] = df['Grade'].replace(grade_map)

# %%
print(grade_map)
# Out:
# {'A': 4, 'B': 3}
