# %%
import pandas as pd

df_emp = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Dept': ['HR', 'HR']
})

df_proj = pd.DataFrame({
    'Project': ['Hiring', 'Training'],
    'Dept': ['HR', 'HR']
})
result = pd.merge(df_emp, df_proj, on='Dept')
print(result)
df_proj_unique = df_proj.drop_duplicates('Dept')
result = pd.merge(df_emp, df_proj_unique, on='Dept')
#print(result)
# Out:
#     Name Dept   Project
# 0  Alice   HR    Hiring
# 1  Alice   HR  Training
# 2    Bob   HR    Hiring
# 3    Bob   HR  Training

# %%
import pandas as pd
df_emp=pd.DataFrame({
    'Name':['Alice','rob'],
    'Dept':['HR','HR']})
df_proj= pd.DataFrame({
    'Proj':['Hiring','Traning'],
    'Dept':['HR','HR']
})
result = df.merge(df_emp,df_proj,on='Dept')
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       2 df_emp=pd.DataFrame({
#       3     'Name':['Alice','rob'],
#       4     'Dept':['HR','HR']})
#       5 df_proj= pd.DataFrame({
#       6     'Proj':['Hiring','Traning'],
#       7     'Dept':['HR','HR']
#       8 })
# ----> 9 result = df.merge(df_emp,df_proj,on='Dept')
#      10 print(result)
#
# NameError: name 'df' is not defined
