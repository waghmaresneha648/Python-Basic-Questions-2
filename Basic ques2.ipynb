# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Name': ['joe','amye','ross','bob'],
                 'Score': [80,85,90,np.nan]})
print(df)
# Out:
#    Name  Score
# 0   joe   80.0
# 1  amye   85.0
# 2  ross   90.0
# 3   bob    NaN
#   Name  Score
# 0  joe   80.0

# %%
low_scores = df[df['Score']<85]
print(low_scores)
# Out:
#   Name  Score
# 0  joe   80.0

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Name':['sneha','riya','priya','jiya'],
                 'score':[25,50,26,np.nan]})
print(df)
print("students list scored less than 50")
lower_score=(df[df['score']<50])
print(lower_score)
# Out:
#     Name  score
# 0  sneha   25.0
# 1   riya   50.0
# 2  priya   26.0
# 3   jiya    NaN
# students list scored less than 50
#     Name  score
# 0  sneha   25.0
# 2  priya   26.0
