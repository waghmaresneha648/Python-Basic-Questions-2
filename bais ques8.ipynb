# %%
#The Row-wise Confusion"Scenario:You have a DataFrame of monthly sales. You want to subtract the Average Sale ($150$) from every single value in the DataFrame to see the variance.

# %%
import pandas as pd

df = pd.DataFrame({
    'Jan': [100, 200],
    'Feb': [150, 180]
})

# Attempting to subtract 150 from everything
result = df - [150, 150]

print("Resulting DataFrame:")
print(result)
# Out:
# Resulting DataFrame:
#    Jan  Feb
# 0  -50    0
# 1   50   30

# %%
df=pd.DataFrame({
    'marks':[100,200,150],
    'feb':
